# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahtesham-Ibne-Mostafa/High_Ram/blob/main/highram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset=pd.read_csv('EEG_HMC_underscore.csv')
dataset1=pd.read_csv('new.csv')

# %%
dataset.head()

# %%
dataset.shape
# Out:
# (108451, 76)

# %%
dataset1.shape
# Out:
# (20410, 121)

# %%
dataset.info()

# %%
dataset.describe()
# Out:
#        MeanP_Alpha_F4  MedianF_Alpha_F4  MeanF_Alpha_F4  \
# count   108451.000000     108451.000000   108451.000000
# mean         0.001315          9.083249       15.611500
# std          0.012327          1.954552        4.051531
# min          0.000000          0.124880        0.874150
# 25%          0.000370          8.366830       13.861460
# 50%          0.000590          9.116100       15.235120
# 75%          0.000940          9.865370       16.733660
# max          1.034330        127.875120      127.875120
#
#        Spectral Edge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  MedianF_Beta_F4  \
# count           108451.000000   108451.000000  108451.000000    108451.000000
# mean                14.831974        9.080123       0.001250        17.282671
# std                  4.324595        5.159732       0.008012        14.226341
# min                  0.124880        0.124880       0.000000         6.243900
# 25%                 12.987320        7.242930       0.000310        12.612680
# 50%                 14.236100        8.366830       0.000480        14.485850
# 75%                 15.859510        9.990240       0.000800        17.108290
# max                127.875120      127.875120       0.577540       127.875120
#
#        MeanF_Beta_F4  Spectral Edge_Beta_F4  PeakF_Beta_F4  ...  \
# count  108451.000000          108451.000000  108451.000000  ...
# mean       27.382434              29.446835      20.378862  ...
# std        13.689974              14.190779      18.889508  ...
# min        14.735610              13.361950       0.124880  ...
# 25%        22.103410              22.727800      10.614630  ...
# 50%        23.976590              25.350240      12.737560  ...
# 75%        27.722930              31.344390      18.981460  ...
# max       127.875120             127.875120     127.875120  ...
#
#        MeanP_Delta_O2  MedianF_Delta_O2  MeanF_Delta_O2  \
# count    1.084510e+05     108451.000000   108451.000000
# mean     2.354664e-02          1.404791        6.631101
# std      1.484228e-01          3.580406        3.279522
# min      2.290000e-40          0.124880        1.373660
# 25%      1.250000e-03          0.749270        5.494630
# 50%      2.640000e-03          0.999020        6.243900
# 75%      6.550000e-03          1.123900        7.118050
# max      7.919750e+00         31.968780       49.826340
#
#        Spectral Edge_Delta_O2  PeakF_Delta_O2  MeanP_Gamma_O2  \
# count           108451.000000   108451.000000   108451.000000
# mean                 3.502748        1.120351        0.001441
# std                  3.530246        3.615241        0.014061
# min                  0.249760        0.124880        0.000000
# 25%                  2.497560        0.499510        0.000030
# 50%                  3.121950        0.624390        0.000055
# 75%                  3.746340        0.874150        0.000180
# max                 32.093660       31.968780        1.179240
#
#        MedianF_Gamma_O2  MeanF_Gamma_O2  Spectral Edge_Gamma_O2  \
# count     108451.000000   108451.000000           108451.000000
# mean          37.196034       44.633561               50.351219
# std           13.848145       11.081070                9.722666
# min           14.610730       27.098540               30.345370
# 25%           28.846830       39.211710               48.327800
# 50%           33.841950       43.082930               49.951220
# 75%           47.453660       49.826340               50.076100
# max          127.875120      127.875120              127.875120
#
#        PeakF_Gamma_O2
# count   108451.000000
# mean        42.621748
# std         15.677343
# min          0.124880
# 25%         32.593170
# 50%         49.951220
# 75%         49.951220
# max        127.875120
#
# [8 rows x 75 columns]

# %%
import csv

with open ('/content/EEG_HMC_underscore.csv','r') as file:
    read=csv.reader(file)
    with open ('new.csv','w') as new_file:
        write=csv.writer(new_file)

        f=0
        for i in read:
            if f==10:
                break
            write.writerow(i)
            f+=1

# %%
import csv

def check(index):
    for i in range(index,index+15):                       
        if index<=i<=index+4 :
            x=round((float(row[i-10])/float(row[i-25])),5)
            talika.append(x)
        elif index+5<=i<=index+9:
            x=round((float(row[i-15])/float(row[i-20])),5)
            talika.append(x)
        elif index+10<=i<=index+14:
            x=round(((float(row[i-20])+float(row[i-25]))/(float(row[i-35])+float(row[i-30]))),5)
            talika.append(str(x))

with open("/content/EEG_HMC_underscore.csv", 'r') as a:
    csv_reader=csv.reader(a)
    
    with open("new.csv", 'w', newline='') as new_file:
        csv_writer=csv.writer(new_file)
        for row in csv_reader:
            talika=[]
            index=0
            for colum in row:
                index+=1
                talika.append(colum)
                if index==26:
                    talika+=['MeanP_DAR_F4','MedianF_DAR_F4','MeanF_DAR_F4','Spectral Edge_DAR_F4', 'PeakF_DAR_F4','MeanP_DTR_F4','MedianF_DTR_F4','MeanF_DTR_F4','Spectral Edge_DTR_F4', 'PeakF_DTR_F4','MeanP_DTABR_F4','MedianF_DTABR_F4','MeanF_DTABR_F4','Spectral Edge_DTABR_F4', 'PeakF_DTABR_F4']
                elif index==51:
                    talika+=['MeanP_DAR_C4','MedianF_DAR_C4','MeanF_DAR_C4','Spectral Edge_DAR_C4', 'PeakF_DAR_C4','MeanP_DTR_C4','MedianF_DTR_C4','MeanF_DTR_C4','Spectral Edge_DTR_C4', 'PeakF_DTR_C4','MeanP_DTABR_C4','MedianF_DTABR_C4','MeanF_DTABR_C4','Spectral Edge_DTABR_C4', 'PeakF_DTABR_C4']
                elif index==76:
                    talika+=['MeanP_DAR_O2','MedianF_DAR_O2','MeanF_DAR_O2','Spectral Edge_DAR_O2', 'PeakF_DAR_O2','MeanP_DTR_O2','MedianF_DTR_O2','MeanF_DTR_O2','Spectral Edge_DTR_O2', 'PeakF_DTR_O2','MeanP_DTABR_O2','MedianF_DTABR_O2','MeanF_DTABR_O2','Spectral Edge_DTABR_O2', 'PeakF_DTABR_O2']

            csv_writer.writerow(talika)
            break
        for row in csv_reader:
            index=0
            talika=[]
            for colum in row: 
                index+=1
                talika.append(colum)
                if index==26 :
                    check(index)
                elif index==51:
                    check(index)
                elif index==76:
                    check(index)
                            
            csv_writer.writerow(talika)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-12-0c50e9eb60a0> in <module>
#      40                 talika.append(colum)
#      41                 if index==26 :
# ---> 42                     check(index)
#      43                 elif index==51:
#      44                     check(index)
#
# <ipython-input-12-0c50e9eb60a0> in check(index)
#       4     for i in range(index,index+15):
#       5         if index<=i<=index+4 :
# ----> 6             x=round((float(row[i-10])/float(row[i-25])),5)
#       7             talika.append(x)
#       8         elif index+5<=i<=index+9:
#
# ZeroDivisionError: float division by zero
